# %% [markdown]
# # Problem Statement
#
# ## Task 1:-Prepare a complete data analysis report on the given data.
#
# ## Task 2:-Create a predictive model with implementation of  different classifiers on liver patient diseases dataset to predict liver diseases.
#
# ## Task3:- Create an analysis to show on what basis you have designed your model.

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('Indian Liver Patient Dataset (ILPD).csv')
data
# Out:
#      65 Female   0.7  0.1  187  16   18  6.8  3.3   0.9  1
# 0    62   Male  10.9  5.5  699  64  100  7.5  3.2  0.74  1
# 1    62   Male   7.3  4.1  490  60   68  7.0  3.3  0.89  1
# 2    58   Male   1.0  0.4  182  14   20  6.8  3.4  1.00  1
# 3    72   Male   3.9  2.0  195  27   59  7.3  2.4  0.40  1
# 4    46   Male   1.8  0.7  208  19   14  7.6  4.4  1.30  1
# ..   ..    ...   ...  ...  ...  ..  ...  ...  ...   ... ..
# 577  60   Male   0.5  0.1  500  20   34  5.9  1.6  0.37  2
# 578  40   Male   0.6  0.1   98  35   31  6.0  3.2  1.10  1
# 579  52   Male   0.8  0.2  245  48   49  6.4  3.2  1.00  1
# 580  31   Male   1.3  0.5  184  29   32  6.8  3.4  1.00  1
# 581  38   Male   1.0  0.3  216  21   24  7.3  4.4  1.50  2
#
# [582 rows x 11 columns]

# %%
data.head()
# Out:
#    65 Female   0.7  0.1  187  16   18  6.8  3.3   0.9  1
# 0  62   Male  10.9  5.5  699  64  100  7.5  3.2  0.74  1
# 1  62   Male   7.3  4.1  490  60   68  7.0  3.3  0.89  1
# 2  58   Male   1.0  0.4  182  14   20  6.8  3.4  1.00  1
# 3  72   Male   3.9  2.0  195  27   59  7.3  2.4  0.40  1
# 4  46   Male   1.8  0.7  208  19   14  7.6  4.4  1.30  1

# %%
data.tail()
# Out:
#      65 Female  0.7  0.1  187  16  18  6.8  3.3   0.9  1
# 577  60   Male  0.5  0.1  500  20  34  5.9  1.6  0.37  2
# 578  40   Male  0.6  0.1   98  35  31  6.0  3.2  1.10  1
# 579  52   Male  0.8  0.2  245  48  49  6.4  3.2  1.00  1
# 580  31   Male  1.3  0.5  184  29  32  6.8  3.4  1.00  1
# 581  38   Male  1.0  0.3  216  21  24  7.3  4.4  1.50  2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   65      582 non-null    int64
#  1   Female  582 non-null    object
#  2   0.7     582 non-null    float64
#  3   0.1     582 non-null    float64
#  4   187     582 non-null    int64
#  5   16      582 non-null    int64
#  6   18      582 non-null    int64
#  7   6.8     582 non-null    float64
#  8   3.3     582 non-null    float64
#  9   0.9     578 non-null    float64
#  10  1       582 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.1+ KB

# %%
data.describe().T
# Out:
#      count        mean         std   min     25%     50%     75%     max
# 65   582.0   44.711340   16.181921   4.0   33.00   45.00   57.75    90.0
# 0.7  582.0    3.303265    6.213926   0.4    0.80    1.00    2.60    75.0
# 0.1  582.0    1.488488    2.810324   0.1    0.20    0.30    1.30    19.7
# 187  582.0  290.754296  243.108929  63.0  175.25  208.00  298.00  2110.0
# 16   582.0   80.824742  182.757696  10.0   23.00   35.00   60.75  2000.0
# 18   582.0  110.068729  289.141876  10.0   25.00   42.00   87.00  4929.0
# 6.8  582.0    6.482646    1.086306   2.7    5.80    6.60    7.20     9.6
# 3.3  582.0    3.141581    0.796176   0.9    2.60    3.10    3.80     5.5
# 0.9  578.0    0.947145    0.319863   0.3    0.70    0.94    1.10     2.8
# 1    582.0    1.286942    0.452723   1.0    1.00    1.00    2.00     2.0

# %%
data1=data.copy()

# %%
data1.duplicated().sum()
# Out:
# 13

# %%
data1.head()
# Out:
#    65 Female   0.7  0.1  187  16   18  6.8  3.3   0.9  1
# 0  62   Male  10.9  5.5  699  64  100  7.5  3.2  0.74  1
# 1  62   Male   7.3  4.1  490  60   68  7.0  3.3  0.89  1
# 2  58   Male   1.0  0.4  182  14   20  6.8  3.4  1.00  1
# 3  72   Male   3.9  2.0  195  27   59  7.3  2.4  0.40  1
# 4  46   Male   1.8  0.7  208  19   14  7.6  4.4  1.30  1

# %%
data1.rename(columns={'65': 'Age of the patient', 'Female': 'Gender of the patient','0.7':'Total Bilirubin','0.1':
                      'Direct Bilirubin','187':'Alkaline Phosphatase','16':'Alanine Aminotransferase','18':
                      'Aspartate Aminotransferase','6.8':'Total Proteins','3.3':'Albumin','0.9':'Albumin and Globulin Ratio',
                      '1':'Target'}, inplace=True)

# %%
data1.head()
# Out:
#    Age of the patient Gender of the patient  Total Bilirubin  \
# 0                  62                  Male             10.9
# 1                  62                  Male              7.3
# 2                  58                  Male              1.0
# 3                  72                  Male              3.9
# 4                  46                  Male              1.8
#
#    Direct Bilirubin  Alkaline Phosphatase  Alanine Aminotransferase  \
# 0               5.5                   699                        64
# 1               4.1                   490                        60
# 2               0.4                   182                        14
# 3               2.0                   195                        27
# 4               0.7                   208                        19
#
#    Aspartate Aminotransferase  Total Proteins  Albumin  \
# 0                         100             7.5      3.2
# 1                          68             7.0      3.3
# ...

# %%
data1.describe()
# Out:
#        Age of the patient  Total Bilirubin  Direct Bilirubin  \
# count          582.000000       582.000000        582.000000
# mean            44.711340         3.303265          1.488488
# std             16.181921         6.213926          2.810324
# min              4.000000         0.400000          0.100000
# 25%             33.000000         0.800000          0.200000
# 50%             45.000000         1.000000          0.300000
# 75%             57.750000         2.600000          1.300000
# max             90.000000        75.000000         19.700000
#
#        Alkaline Phosphatase  Alanine Aminotransferase  \
# count            582.000000                582.000000
# mean             290.754296                 80.824742
# std              243.108929                182.757696
# min               63.000000                 10.000000
# 25%              175.250000                 23.000000
# 50%              208.000000                 35.000000
# ...

# %%
data1.isnull().sum()
# Out:
# Age of the patient            0
# Gender of the patient         0
# Total Bilirubin               0
# Direct Bilirubin              0
# Alkaline Phosphatase          0
# Alanine Aminotransferase      0
# Aspartate Aminotransferase    0
# Total Proteins                0
# Albumin                       0
# Albumin and Globulin Ratio    4
# Target                        0
# dtype: int64

# %%
data1=data1.fillna(data1.mean())

# %%
data1.isnull().sum()
# Out:
# Age of the patient            0
# Gender of the patient         0
# Total Bilirubin               0
# Direct Bilirubin              0
# Alkaline Phosphatase          0
# Alanine Aminotransferase      0
# Aspartate Aminotransferase    0
# Total Proteins                0
# Albumin                       0
# Albumin and Globulin Ratio    0
# Target                        0
# dtype: int64

# %%
data1.describe(include="O").T
# Out:
#                       count unique   top freq
# Gender of the patient   582      2  Male  441

# %%
data1.duplicated().sum()
# Out:
# 13

# %% [markdown]
# I didnt removed these because it might effect our accuracy.

# %% [markdown]
# ## Task 1:-Prepare a complete data analysis report on the given data.

# %% [markdown]
# # Visualisation & Analysis

# %%
# Explore relationships between features and the target variable
plt.figure(figsize=(15, 8))
sns.heatmap(data1.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Based on the above heatmap we can see that no column is correlated with each other.

# %%
for column in data1.columns:
    if data1[column].dtype == 'O':
        # For categorical features, use bar plots
        plt.figure(figsize=(10, 6))
        sns.countplot(x=column, data=data1, palette='viridis')
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Count')
        plt.xticks(rotation=45)
        plt.show()
    else:
        # For numerical features, use histograms
        plt.figure(figsize=(10, 6))
        sns.histplot(data1[column], bins=30, kde=True, color='skyblue')
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
        plt.show()

# %%
plt.figure(figsize=(4, 4))
sns.barplot(x='Gender of the patient', y='Aspartate Aminotransferase', data=data1, ci=None, palette='viridis')
plt.title('Average Aspartate Aminotransferase by Gender')
plt.xlabel('Gender of the patient')
plt.ylabel('Average Aspartate Aminotransferase')
plt.show()

# %% [markdown]
# Analysis about Age: Here we can see that people between 30 to 60 years old are the most admitted and people between 5 to 20 and 70 to 80 are the least admitted for liver disease.
#
# Analysis about Gender: Here we can see that males are the most admitted compared to females for liver disease.
#
# Analysis about Bilirubin: Here we can see in total bilirubin that most of the values are in between 0 and 1 which is a good bilirubin but some values went above 2 which means some patients are having liver diseases, in the direct bilirubin most of the values are in between 0.0 to 0.3(as i assume) which is the normal values for direct dilirubin but we can see some values went above 0.5 which means some patients are having liver diseases.
#
# Analysis about Alkaline Phosphatase: Here we can see that most of the values are mostly between 50-150(as i assume) which are the normal values for Alkaline Phosphatase and some values went above 150 which means there are patients with liver diseases.
#
# Analysis about Alanine Aminotransferase: Here we can see that most values are between 7-57(as i assume) which are the normal values for Alanine Aminotransferase but some went above 57 which means some patients are having liver diseases.
#
# Analysis about Aspartate Aminotransferase: Here we can see that most values are between [Men: 14 to 20 units/L. Women: 10 to 36 units/L.] 10-36(as i assume) but some values are went above 36 which means some patients are having liver diseases.
#
# Analysis about Total Proteins: Here we can see that most total proteins are at 7 which is a good value and some are between 3 to 6 and some are after 8 which means there are some patients who are having liver diseases.
#
# Analysis about Albumin: Here we can see that most Albumin is at 3 which is a good value and some are between 1 to 3 and after 5 which means there are some patients who are having liver diseases.
#
# Analysis about Albumin and Globulin Ratio: Here we can see that most Albumin and Globulin Ratio is at 1.0 which is a good value and some are before 1.0 and some went after 2.0 which means some patients are having liver diseases.
#
# Analysis about Target: Here we can see that most patients are having liver diseases which is 1 and less patients are not having liver diseases that is 2.

# %% [markdown]
# # Visualisation & Analysis based on Target

# %%
#Histogram

columns=data1[['Total Bilirubin','Direct Bilirubin','Alkaline Phosphatase','Alanine Aminotransferase',
               ,'Albumin and Globulin Ratio']]

for column in columns:
        plt.figure(figsize=(10, 6))
        sns.histplot(data=data1, x=data1[column], hue='Target', palette='cividis', bins=30, kde=True)
        plt.title(f'Distribtion for {column}')
        plt.xlabel(column,fontsize=20)
        plt.ylabel('Target',fontsize=20)
        plt.xticks(rotation=90)
        plt.show()

# %%
#Barplot
plt.figure(figsize=(20, 15))
sns.countplot(x='Age of the patient', data=data1, hue='Target')
plt.title('Countplot for Age of the patient by Target')
plt.show()

plt.figure(figsize=(20, 15))
sns.countplot(x='Gender of the patient', data=data1, hue='Target')
plt.title('Countplot for Gender by Target')
plt.show()

plt.figure(figsize=(20, 15))
sns.countplot(x='Total Proteins', data=data1, hue='Target')
plt.title('Countplot for Total Proteins by Target')
plt.show()

plt.figure(figsize=(20, 15))
sns.countplot(x='Albumin', data=data1, hue='Target')
plt.title('Countplot for Albumin by Target')
plt.show()

# %% [markdown]
# Analysis about Age based on Target: Based on the graph we can say that the liver diseases gonna start from 18. At the age of 31,45,60(highest liver diseases occurance age),75 we can see more liver diseases cases. At every age we can see that there are some liver diseases occuring. Least occurance of liver diseases can be seen at these ages i.e.,...19,20,23,27,56,63,67,69,78,90. So as per this we can say that after 7 years old we can see that most of the people are having liver diseases.
#
# Analysis about Gender based on Target: Based on the graph we can say that most males are having liver diseases compared to females. Highest males are having no liver diseases compared to females.
#
# Analysis about Total Bilirubin based on Target: Based on the graph we can say that highest liver diseases patients are having total Bilirubin after 5 and we can see that highest patients who are not having liver diseases are having total Bilirubin of 0 to 5.
#
# Analysis about Direct Bilirubin based on Target: Based on the graph we can say that highest liver diseases patients are having Direct Bilirubin of 1.5 and we can see that highest patients who are not having liver diseases are having Direct Bilirubin of 0 to 1(as i assume)
#
# Analysis about Alkaline Phosphatase based on Target:  Based on the graph we can say most of the patients are having liver diseases even tho they have low Alkaline Phosphatase they still have diseases. Only some are having no liver diseases.
#
# Analysis about Alanine Aminotransferase based on target: Based on the graph we can say that highest liver diseases patients are having Alanine Aminotransferase after 100 and we can see that highest patients who are not having liver diseases are having Alanine Aminotransferase in between 0 to 100 but still we can see that some patients are having liver diseases even tho their Alanine Aminotransferase lies in between 0 to 100.
#
# Analysis about Total Proteins based on Target: Based on the graph we can say that highest liver diseases patients are having total proteins of 6.9 to 7.5 and we can see that highest patients who are not having liver diseases are having total proteins of 6.0 and 7.0.
#
# Analysis about Albumin based on Target: Based on the graph we can say that highest liver diseases patients are having Albumin of  3.0 and 4.0 and we can see that highest patients who are not having liver diseases are having Albumin of 4.2 and 4.4. But we can see most of the patients are having liver diseases even tho they have good Albumin values.

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
data1['Gender of the patient'] = le.fit_transform(data1['Gender of the patient'])

# %% [markdown]
# We changed categorical columns to numerical values.

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age of the patient          582 non-null    int64
#  1   Gender of the patient       582 non-null    int32
#  2   Total Bilirubin             582 non-null    float64
#  3   Direct Bilirubin            582 non-null    float64
#  4   Alkaline Phosphatase        582 non-null    int64
#  5   Alanine Aminotransferase    582 non-null    int64
#  6   Aspartate Aminotransferase  582 non-null    int64
#  7   Total Proteins              582 non-null    float64
#  8   Albumin                     582 non-null    float64
#  9   Albumin and Globulin Ratio  582 non-null    float64
#  10  Target                      582 non-null    int64
# dtypes: float64(5), int32(1), int64(5)
# memory usage: 47.9 KB

# %%
print(data1['Target'].unique())
# Out:
# [1 2]

# %%
data1['Target'] = data1['Target'].replace(2, 0)

# %% [markdown]
# I replaced this beccause i wanted XG Boosting model and my data is not supported with XG boosting model so i have to replace the unique values in the Target column.

# %% [markdown]
#  # Scaling the Values and separating independent to x and dependent to y

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler object
scaler = StandardScaler()
# Split x and y
x = data1.drop(columns = ['Target'],axis=1) # Independent variables
y = data1['Target'] # Dependent / target variable

# %%
# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to the data
scaler.fit(x, y)

# Transform the data
x_std = scaler.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
x_train
# Out:
#      Age of the patient  Gender of the patient  Total Bilirubin  \
# 38                   47                      1              2.7
# 432                  41                      0              0.9
# 288                  57                      1              4.5
# 517                  45                      1              2.9
# 179                  75                      1              2.8
# ..                  ...                    ...              ...
# 393                  48                      0              1.0
# 75                   31                      1              0.9
# 575                  32                      1             15.0
# 337                  75                      1              1.8
# 523                  29                      1              0.8
#
#      Direct Bilirubin  Alkaline Phosphatase  Alanine Aminotransferase  \
# 38                1.3                   275                       123
# ...

# %%
x_test
# Out:
#      Age of the patient  Gender of the patient  Total Bilirubin  \
# 227                  65                      0              1.0
# 128                  45                      1              2.8
# 428                  73                      1              1.9
# 141                  30                      1              1.6
# 422                  53                      1              1.6
# ..                  ...                    ...              ...
# 536                  10                      0              0.8
# 567                  20                      0             16.7
# 317                  38                      1              3.7
# 333                  13                      0              0.7
# 127                  58                      0              1.7
#
#      Direct Bilirubin  Alkaline Phosphatase  Alanine Aminotransferase  \
# 227               0.3                   202                        26
# ...

# %%
y_train
# Out:
# 38     1
# 432    0
# 288    1
# 517    1
# 179    1
#       ..
# 393    1
# 75     1
# 575    1
# 337    1
# 523    0
# Name: Target, Length: 407, dtype: int64

# %%
y_test
# Out:
# 227    0
# 128    1
# 428    1
# 141    1
# 422    0
#       ..
# 536    1
# 567    1
# 317    1
# 333    1
# 127    1
# Name: Target, Length: 175, dtype: int64

# %% [markdown]
# ## Task 2:-Create a predictive model with implementation of  different classifiers on liver patient diseases dataset to predict liver diseases.

# %% [markdown]
# # Model Creation

# %% [markdown]
# # Logistic Classification Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
logistic_regression_model = LogisticRegression()

# %%
logistic_regression_model.fit(x,y)
# Out:
# LogisticRegression()

# %%
y_pred = logistic_regression_model.predict(x_test)

# %%
log1_accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {log1_accuracy:.2f}")
# Out:
# Accuracy: 0.70

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# %%
# Define the hyperparameter grid to search
param_grid = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100]
}

# %%
# Use GridSearchCV to search for the best hyperparameters
grid_search = GridSearchCV(estimator=logistic_regression_model, param_grid=param_grid, scoring='accuracy', cv=5)
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'penalty': ['l1', 'l2']},
#              scoring='accuracy')

# %%
# Get the best hyperparameters
best_params = grid_search.best_params_
print(f'Best Hyperparameters: {best_params}')
# Out:
# Best Hyperparameters: {'C': 0.001, 'penalty': 'l2'}

# %%
# Use the best model to make predictions
best_logreg_model = grid_search.best_estimator_
y_pred = best_logreg_model.predict(x_test)

# %%
# Evaluate the model
log_accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy on Test Set: {log_accuracy:.2f}')
# Out:
# Accuracy on Test Set: 0.75

# %%
from sklearn.metrics import roc_curve, auc
# Assuming your original target variable is in 'y'
# Use LabelEncoder to convert {1, 2} to {0, 1}
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Assuming you have a trained logistic regression model named 'logreg'
# Make sure to replace 'logreg' with the actual variable name of your logistic regression model
fpr, tpr, _ = roc_curve(y_encoded, logistic_regression_model.predict_proba(x)[:, 1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Logistic Regression')
plt.legend()
plt.show()

# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.33      0.43        49
#            1       0.78      0.92      0.84       126
#
#     accuracy                           0.75       175
#    macro avg       0.70      0.62      0.64       175
# weighted avg       0.73      0.75      0.73       175

# %% [markdown]
# Based on the graph we can say 75% of the observations are correctly predicted and it has an area of 76 which is a good performance in distinguishing between positive and negative instances. The model is achieving a high True Positive Rate while keeping the False Positive Rate low which means it as a good model.

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
decision_tree_classifier = DecisionTreeClassifier(random_state=42)

# %%
decision_tree_classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = decision_tree_classifier.predict(x_test)

# %%
dt_accuracy = accuracy_score(y_test, y_pred)

# %%
fpr, tpr, _ = roc_curve(y_encoded, decision_tree_classifier.predict_proba(x)[:, 1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Decision Tree Classifier')
plt.legend()
plt.show()
# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.43      0.41        49
#            1       0.77      0.75      0.76       126
#
#     accuracy                           0.66       175
#    macro avg       0.58      0.59      0.58       175
# weighted avg       0.67      0.66      0.66       175

# %% [markdown]
# Based on the graph we can say 66% of the observations are correctly predicted and it has an area of 88 which is a good performance in distinguishing between positive and negative instances. The model is achieving a high True Positive Rate while keeping the False Positive Rate low which means it as a good model.

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rf_classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_classifier.predict(x_test)

# %%
rd_accuracy = accuracy_score(y_test, y_pred)
print(rd_accuracy)
# Out:
# 0.6685714285714286

# %%
fpr, tpr, _ = roc_curve(y_encoded, rf_classifier.predict_proba(x)[:, 1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Random Forest Classifier')
plt.legend()
plt.show()

# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.35      0.37        49
#            1       0.76      0.79      0.78       126
#
#     accuracy                           0.67       175
#    macro avg       0.58      0.57      0.57       175
# weighted avg       0.66      0.67      0.66       175

# %% [markdown]
# Based on the graph we can say 67% of the observations are correctly predicted and it has an area of 95 which is a good performance in distinguishing between positive and negative instances. The model is achieving a high True Positive Rate while keeping the False Positive Rate low which means it as a good model.

# %% [markdown]
# # Support Vector Model

# %%
from sklearn.svm import SVC

# %%
svm_classifier = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42)

# %%
svm_classifier.fit(x_train, y_train)
# Out:
# SVC(random_state=42)

# %%
y_pred = svm_classifier.predict(x_test)
svc_accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy on Test Set: {svc_accuracy:.2f}')
# Out:
# Accuracy on Test Set: 0.72

# %%
# Assuming your original target variable is in 'y'
# Use LabelEncoder to convert {1, 2} to {0, 1}
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Assuming you have features in 'X' and target variable in 'y'
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

# Assuming you have a trained SVM model
# Make sure to replace 'svm_model' with the actual variable name of your SVM model
svm_model = SVC(probability=True)  # Assuming a basic SVM model, you may need to adjust hyperparameters
svm_model.fit(x_train, y_train)

# Calculate ROC curve
fpr, tpr, _ = roc_curve(y_test, svm_model.predict_proba(x_test)[:, 1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for SVM')
plt.legend()
plt.show()

# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))

# %% [markdown]
# Based on the graph we can say 72% of the observations are correctly predicted and it has an area of 71 which is a good performance in distinguishing between positive and negative instances. The model is correctly identifying positive instances with high sensitivity but also making a significant number of false positive errors.

# %% [markdown]
# # Boosting Model

# %%
#from sklearn import decision tree
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()#object creation for decision Tree
dt.fit(x_train,y_train)#training model
y_hat=dt.predict(x_test)#prediction

# %%
#test acc
test_acc=accuracy_score(y_test,y_hat)#testing accuracy
test_acc
# Out:
# 0.6495726495726496

# %%
## importing the model library
from sklearn.ensemble import GradientBoostingClassifier
gbm=GradientBoostingClassifier() ## object creation
gbm.fit(x_train,y_train) ## fitting the data
y_gbm=gbm.predict(x_test)#predicting the price

# %%
## evaluatin the model
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score,classification_report# to check model performance
accu_scor=accuracy_score(y_test,y_gbm)
accu_scor
# Out:
# 0.6923076923076923

# %%
import xgboost

# %%
## model creation
from xgboost import XGBClassifier#importing the model library
xgb_r=XGBClassifier() ## object creation

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 465 entries, 433 to 102
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age of the patient          465 non-null    int64
#  1   Gender of the patient       465 non-null    int32
#  2   Total Bilirubin             465 non-null    float64
#  3   Direct Bilirubin            465 non-null    float64
#  4   Alkaline Phosphatase        465 non-null    int64
#  5   Alanine Aminotransferase    465 non-null    int64
#  6   Aspartate Aminotransferase  465 non-null    int64
#  7   Total Proteins              465 non-null    float64
#  8   Albumin                     465 non-null    float64
#  9   Albumin and Globulin Ratio  465 non-null    float64
# dtypes: float64(5), int32(1), int64(4)
# memory usage: 38.1 KB

# %%
x_train['Total Bilirubin']=x_train['Total Bilirubin'].astype('int64')
x_train['Direct Bilirubin']=x_train['Direct Bilirubin'].astype('int64')
x_train['Total Proteins']=x_train['Total Proteins'].astype('int64')
x_train['Albumin']=x_train['Albumin'] .astype('int64')
x_train['Albumin and Globulin Ratio']=x_train['Albumin and Globulin Ratio'].astype('int64')

# %%
## model creation
from xgboost import XGBClassifier#importing the model library
xgb_r=XGBClassifier() ## object creation
xgb_r.fit(x_train,y_train)# fitting the data
y_hat=xgb_r.predict(x_test)#predicting the price range
xgb1_accuracy=accuracy_score(y_test,y_hat)
print(xgb1_accuracy)
# Out:
# 0.6923076923076923

# %%
param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200, 300],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
}

# %%
grid_search = GridSearchCV(estimator=xgb_r, param_grid=param_grid, scoring='accuracy', cv=3, n_jobs=-1)

# %%
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
# ...

# %%
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'colsample_bytree': 0.9, 'learning_rate': 0.2, 'max_depth': 7, 'n_estimators': 100, 'subsample': 0.9}

# %%
best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)

# %%
xgb_accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", xgb_accuracy)
# Out:
# Accuracy: 0.717948717948718

# %%
fpr, tpr, _ = roc_curve(y_encoded, xgb_r.predict_proba(x)[:, 1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for XG Boosting Classifier')
plt.legend()
plt.show()

# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.43      0.45      0.44        29
#            1       0.82      0.81      0.81        88
#
#     accuracy                           0.72       117
#    macro avg       0.62      0.63      0.63       117
# weighted avg       0.72      0.72      0.72       117

# %% [markdown]
# Based on the graph we can say 72% of the observations are correctly predicted and it has an area of 97 which is a good performance in distinguishing between positive and negative instances. The model is achieving a high True Positive Rate while keeping the False Positive Rate low which means it as a good model.

# %% [markdown]
# # KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create KNN classifier with K=3 (for example)
knn = KNeighborsClassifier(n_neighbors=3)

# Fit the model to the training data
knn.fit(x_train, y_train)

# Make predictions on the test data
y_pred = knn.predict(x_test)

# %%
knn_accuracy = accuracy_score(y_test, y_pred)

# %%
# Calculate ROC curve
fpr, tpr, _ = roc_curve(y_test, knn.predict_proba(x_test)[:, 1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for KNN')
plt.legend()
plt.show()
# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.29      0.34      0.31        29
#            1       0.77      0.72      0.74        88
#
#     accuracy                           0.62       117
#    macro avg       0.53      0.53      0.53       117
# weighted avg       0.65      0.62      0.63       117

# %% [markdown]
# Based on the graph we can say 62% of the observations are correctly predicted and it has an area of 60 which is a good performance in distinguishing between positive and negative instances. The model is performing well in terms of sensitivity (correctly identifying positives) but may be less specific (potentially more false positives).

# %% [markdown]
# # Navie Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# Create Gaussian Naive Bayes classifier
naive_bayes = GaussianNB()

# Fit the model to the training data
naive_bayes.fit(x_train, y_train)

# Make predictions on the test data
y_pred = naive_bayes.predict(x_test)

# %%
nav_accuracy = accuracy_score(y_test, y_pred)

# %%
# Calculate ROC curve
fpr, tpr, _ = roc_curve(y_test, naive_bayes.predict_proba(x_test)[:, 1])
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Navie Bayes')
plt.legend()
plt.show()

# Print classification report
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.31      0.97      0.47        29
#            1       0.96      0.31      0.47        88
#
#     accuracy                           0.47       117
#    macro avg       0.64      0.64      0.47       117
# weighted avg       0.80      0.47      0.47       117

# %% [markdown]
# Based on the graph we can say 47% of the observations are correctly predicted and it has an area of 69 which is a good performance in distinguishing between positive and negative instances. The model is performing well in terms of sensitivity (correctly identifying positives) but may be less specific (potentially more false positives).

# %% [markdown]
# # Model Representation

# %%
scores=[log_accuracy,dt_accuracy,rd_accuracy,svc_accuracy,xgb_accuracy,knn_accuracy,nav_accuracy]
algorithms=['Logistic Classifier','Decision Tree Regression','Random Forest Classification','Support Vector Classifier',
            'XG Boosting Classifier','KNN Classifier','Naive Bayes']
for i in range(len(algorithms)):
    print("The Accuracy acheived using " + algorithms[i] + ' is: ' + str(scores[i])+"%")
# Out:
# The Accuracy acheived using Logistic Classifier is: 0.7542857142857143%
# The Accuracy acheived using Decision Tree Regression is: 0.6571428571428571%
# The Accuracy acheived using Random Forest Classification is: 0.6685714285714286%
# The Accuracy acheived using Support Vector Classifier is: 0.72%
# The Accuracy acheived using XG Boosting Classifier is: 0.717948717948718%
# The Accuracy acheived using KNN Classifier is: 0.6239316239316239%
# The Accuracy acheived using Naive Bayes is: 0.4700854700854701%

# %%
# plotting the barplot between algoriths and their r2_scores
plt.figure(figsize=(8,6))
plt.xlabel("Algorithms")
plt.ylabel("Accuracy")
ax=sns.barplot(x=algorithms,y=scores)
for label in ax.containers:
    ax.bar_label(label)
    plt.xticks(rotation=90)
plt.tight_layout()
plt.tick_params(labelsize=9)

# %% [markdown]
# ## Task3:- Create an analysis to show on what basis you have designed your model.

# %% [markdown]
# # Report/ Conclusion

# %% [markdown]
# **Project Report: Liver Disease Prediction**
#
# **Problem Statement:**
#
# The increasing prevalence of liver diseases due to factors like excessive alcohol consumption, exposure to harmful gases, consumption of contaminated food, pickles, and drugs poses a significant challenge. Predicting liver disease in patients can aid in timely medical intervention and reduce the burden on healthcare professionals. In this project, our goal is to perform a comprehensive data analysis and develop predictive models using different classifiers on a liver patient dataset.
#
# **1. Data Exploration and Cleaning:**
#    - Explored the dataset containing liver patient records and non-liver patient records.
#    - Checked for basic information, null values, and statistical descriptions.
#    - Renamed columns for better readability and understanding.
#    - Handled null values in the 'Albumin and Globulin Ratio' column by replacing them with the mean.
#
# **2. Data Visualization:**
#    - Explored the correlation among numerical features using a heatmap.
#    - Utilized bar plots for categorical features and histograms for numerical features to gain insights.
#    - Analyzed the distribution of data for each attribute, identifying potential patterns and outliers.
#    - Created visualizations based on the target variable ('liver disease') to understand the impact of different features.
#
# **3. Data Analysis:**
#    - Analyzed patient age, gender, and various biochemical markers concerning liver diseases.
#    - Identified trends in liver diseases based on different features such as bilirubin levels, alkaline phosphatase, and liver enzymes.
#    - Provided insights into the distribution of liver diseases across age groups and genders.
#
# **4. Data Preprocessing:**
#    - Performed label encoding for the 'Gender' column.
#    - Checked unique values in the 'Target' column and replaced them to facilitate model training.
#    - Applied standard scaling to normalize numerical features.
#
# **5. Model Building:**
#    - Split the data into training and testing sets.
#    - Employed logistic regression and achieved an initial accuracy of 70%.
#    - Conducted hyperparameter tuning, improving accuracy to 75%.
#    - Implemented decision tree, random forest, and support vector machine (SVM) models.
#    - Utilized boosting models (Gradient Boosting, XG Boosting) and achieved competitive results.
#    - Applied K-Nearest Neighbors (KNN) and Naive Bayes for classification.
#
# **6. Model Evaluation:**
#    - Utilized ROC curves to assess the performance of each model.
#    - Analyzed True Positive Rate (Sensitivity) and False Positive Rate for model comparison.
#    - Provided detailed insights into the strengths and weaknesses of each model.
#
# **7. Conclusion:**
#    - XG Boosting and Random Forest exhibited the best performance with ROC AUC scores of 71% and 95%, respectively.
#    - Logistic regression, Decision Tree, and SVM also provided reasonable accuracy.
#    - Considered factors such as sensitivity, specificity, and overall ROC curve shape for model selection.
#
# **8. Recommendations:**
#    - Further fine-tuning of hyperparameters for Logistic Classifier & XG Boosting model.
#    - Collect additional data to enhance model performance.
#    - Consider domain-specific features that might contribute to improved predictions.
#
# **9. Visualizations and Insights:**
#    - Provided visualizations for each step of the analysis, enhancing interpretability.
#    - Analyzed age, gender, and biochemical markers in the context of liver diseases.
#    - Visualized the distribution of liver diseases across different features, aiding in pattern identification.
#
# **10. Future Work:**
#    - Explore more advanced ensemble methods for better prediction.
#    - Investigate the impact of additional features on model performance.
#    - Implement cross-validation techniques for robust model evaluation.
#
# **11. Acknowledgments:**
#    - Acknowledged the context and significance of the dataset in the domain of healthcare.
#    - Highlighted the importance of leveraging machine learning for predicting liver diseases and reducing the burden on healthcare professionals.
#
# The project successfully addressed the problem of liver disease prediction using a liver patient dataset. Through detailed data analysis and the implementation of various classifiers, we gained insights into the dataset's characteristics. The models showed varying levels of accuracy and performance, with Random Forest and XGBoosting demonstrating higher efficacy. The ROC curves provided a visual representation of the models' ability to distinguish between positive and negative instances. The analysis contributes to building a predictive model for liver disease, offering potential benefits for early diagnosis and intervention.
